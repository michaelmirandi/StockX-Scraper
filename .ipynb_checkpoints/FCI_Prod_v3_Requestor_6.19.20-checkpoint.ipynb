# %%
#Creating automated traversal of result pages

import os
import csv
import time
import requests
import datetime
import traceback
import pandas as pd
import dateutil.parser
import yaml
import pymongo
import dns
from bs4 import BeautifulSoup
from datetime import timedelta
from ebaysdk import finding
from ebaysdk.finding import Connection as Finding
from ebaysdk.shopping import Connection as Shopping
from ebaysdk.exception import ConnectionError
from ebay.shopping import GetMultipleItems 

#requestor class
class Requestor():
    
    #returns the total pages from findCompletedItems call
    def getTotalPages(self, key, page):
        api = Finding(domain='svcs.ebay.com', appid='SoleML--PRD-a2eba3d7e-8cd42d5c', config_file=None)
        self.key = key
        self.page = page
        response = api.execute('findCompletedItems',  {'keywords': key, 'paginationInput': {'pageNumber' : page}})
        res_dict = response.dict()
        total_pages = res_dict['paginationOutput']['totalPages']
        return int(total_pages)
    
    #fetches (page) of findCompletedItems result for (key)
    def main(self, key, page, transactions_db):
        #make initial request to retrieve first page of results and determine total pages
        api = Finding(domain='svcs.ebay.com', appid='SoleML--PRD-a2eba3d7e-8cd42d5c', config_file=None)
        self.key = key
        self.page = page
        self.transactions_db = transactions_db
        
        response = api.execute('findCompletedItems',  {'keywords': key, 'paginationInput': {'pageNumber' : page}})
        res_dict = response.dict()
        total_pages = res_dict['paginationOutput']['totalPages']
        search_result = res_dict['searchResult']

        i = 0
        #loop to print out each item 
        while i < len(search_result['item']):
            items = search_result['item'][i]  
            print(items)
            break
            
            #set variables
            title = items['title']
            price = items['sellingStatus']['currentPrice']['value']
            currency = items['sellingStatus']['currentPrice']['_currencyId']
            endTime = items['listingInfo']['endTime']
            
            lowTitle = title.lower()
            lt = lowTitle.split()
            
            if "size" in lowTitle:
                size = lowTitle.partition("size")[2]
                try:
                    size = size.split()[0]
                except IndexError:
                    size = ""
            elif " s " in lowTitle:
                size = lowTitle.partition(" s ")[2]
                try:
                    size = size.split()[0]
                except IndexError:
                    size = ""
            elif "sz" in lowTitle:
                size = lowTitle.partition("sz")[2]
                try:
                    size = size.split()[0]
                except IndexError:
                    size = ""
            else:
                size = ""
            
            transaction = {'title': title, 'price': price, 'currency': currency, 'size': size, 'endTime' : endTime}
            transactions_db.insert_one(transaction)
            #print for visual swag right now
            #print(title, "//", price, currency, "//", endTime)
            i = i + 1



        #print(search_result)

#print(res_dict)
#print(total_pages)



#list_of_keys = {"Jordan 13 Retro Flint 2020", "Jordan 1 Retro High Royal Toe"}

#connect to mongo client and point to correct 
#client = pymongo.MongoClient("mongodb+srv://soelml:WheresMyBelt29!@soleml-sandbox-s5fy7.mongodb.net/SoleML?retryWrites=true&w=majority")
#db = client.Test
#collection_products = db.testProducts
#collection_transactions = db.testEbayTransactions



#iterate through documents in product table and use product name to search ebay for matching products
#for doc in collection_products.find({}, {"_id": 0, "name": 1}):
 #   print(doc)
 #   #create requestor Object
 #   r = Requestor()
 #   t = r.getTotalPages(doc['name'], 1)
 #   #t = 2
 #   x = 1
 #   while x <= t:
  #      r.main(doc['name'], x, collection_transactions)
  #      x+=1

#for key in list_of_keys:
    #r = Requestor()
    #t = r.getTotalPages(key, 1)
    #t = 2
    #x = 1
    #while x <= t:
        #r.main(key, x)
        #x+=1
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-17-65884a857e89> in <module>
#      18 from ebaysdk.shopping import Connection as Shopping
#      19 from ebaysdk.exception import ConnectionError
# ---> 20 from ebay.shopping import GetMultipleItems
#      21
#      22 #requestor class
#
# ~\Anaconda3\lib\site-packages\ebay\shopping.py in <module>
#       1 import requests
# ----> 2 from utils import get_config_store
#       3
#       4
#       5 # Item Search
#
# ModuleNotFoundError: No module named 'utils'

# %%
api = Finding(domain='svcs.ebay.com', appid='SoleML--PRD-a2eba3d7e-8cd42d5c', config_file=None)
response = api.execute('findCompletedItems',  {'keywords': 'Jordan 13 Retro Flint (2020)', 
                                               'paginationInput': {'pageNumber' : 2},
                                              'IncludeSelector':'ItemSpecifics'})

# %%
response.dict()
# Out:
# {'ack': 'Success',
#  'version': '1.13.0',
#  'timestamp': '2020-06-21T05:20:37.735Z',
#  'searchResult': {'item': [{'itemId': '233605037047',
#     'title': '2020 Nike Air Jordan 13 Flint Retro Order Confirmed MULTIPLE SIZES AVAILABLE!',
#     'globalId': 'EBAY-US',
#     'primaryCategory': {'categoryId': '15709',
#      'categoryName': 'Athletic Shoes'},
#     'galleryURL': 'https://thumbs4.ebaystatic.com/pict/2336050370474040_1.jpg',
#     'viewItemURL': 'https://www.ebay.com/itm/2020-Nike-Air-Jordan-13-Flint-Retro-Order-Confirmed-MULTIPLE-SIZES-AVAILABLE-/233605037047?var=533290761839',
#     'paymentMethod': 'PayPal',
#     'autoPay': 'false',
#     'postalCode': '152**',
#     'location': 'Pittsburgh,PA,USA',
#     'country': 'US',
#     'shippingInfo': {'shippingType': 'Calculated',
#      'shipToLocations': 'Worldwide',
#      'expeditedShipping': 'true',
#      'oneDayShippingAvailable': 'false',
#      'handlingTime': '2'},
#     'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '260.0'},
#      'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '260.0'},
#      'sellingState': 'EndedWithSales'},
#     'listingInfo': {'bestOfferEnabled': 'false',
#      'buyItNowAvailable': 'false',
#      'startTime': '2020-05-31T07:47:32.000Z',
#      'endTime': '2020-06-20T14:11:29.000Z',
#      'listingType': 'FixedPrice',
#      'gift': 'false'},
#     'returnsAccepted': 'false',
#     'condition': {'conditionId': '1000',
#      'conditionDisplayName': 'New with box'},
#     'isMultiVariationListing': 'true',
#     'topRatedListing': 'false'},
#    {'itemId': '124227507486',
#     'title': 'Nike Air Jordan Retro 13 XIII Flint Size 13 414571-404 NEW DS 2020',
#     'globalId': 'EBAY-US',
#     'primaryCategory': {'categoryId': '15709',
#      'categoryName': 'Athletic Shoes'},
#     'galleryURL': 'https://thumbs3.ebaystatic.com/m/mJx5lcXbylNDNiNtFQhIcRA/140.jpg',
#     'viewItemURL': 'https://www.ebay.com/itm/Nike-Air-Jordan-Retro-13-XIII-Flint-Size-13-414571-404-NEW-DS-2020-/124227507486',
#     'paymentMethod': 'PayPal',
#     'autoPay': 'false',
#     'postalCode': '956**',
#     'location': 'Citrus Heights,CA,USA',
#     'country': 'US',
#     'shippingInfo': {'shippingServiceCost': {'_currencyId': 'USD',
#       'value': '10.0'},
#      'shippingType': 'FlatDomesticCalculatedInternational',
#      'shipToLocations': 'Worldwide',
#      'expeditedShipping': 'true',
#      'oneDayShippingAvailable': 'false',
#      'handlingTime': '3'},
#     'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '250.0'},
#      'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '250.0'},
#      'bidCount': '1',
#      'sellingState': 'EndedWithSales'},
#     'listingInfo': {'bestOfferEnabled': 'false',
#      'buyItNowAvailable': 'false',
#      'startTime': '2020-06-18T13:11:51.000Z',
#      'endTime': '2020-06-20T13:54:25.000Z',
#      'listingType': 'Auction',
#      'gift': 'false',
#      'watchCount': '7'},
#     'returnsAccepted': 'false',
#     'condition': {'conditionId': '1000',
#      'conditionDisplayName': 'New with box'},
#     'isMultiVariationListing': 'false',
#     'topRatedListing': 'false'},
#    {'itemId': '324184676786',
#     'title': '2020 Nike Air Jordan 13 Retro XIII Flint 3M Reflective Grey 414571-404 Size 4-15',
#     'globalId': 'EBAY-US',
#     'primaryCategory': {'categoryId': '15709',
#      'categoryName': 'Athletic Shoes'},
#     'galleryURL': 'https://thumbs3.ebaystatic.com/pict/3241846767864040_3.jpg',
#     'viewItemURL': 'https://www.ebay.com/itm/2020-Nike-Air-Jordan-13-Retro-XIII-Flint-3M-Reflective-Grey-414571-404-Size-4-15-/324184676786?var=513255588576',
#     'paymentMethod': 'PayPal',
#     'autoPay': 'true',
#     'postalCode': '191**',
#     'location': 'Philadelphia,PA,USA',
#     'country': 'US',
#     'shippingInfo': {'shippingServiceCost': {'_currencyId': 'USD',
#       'value': '0.0'},
#      'shippingType': 'FlatDomesticCalculatedInternational',
#      'shipToLocations': 'Worldwide',
#      'expeditedShipping': 'true',
#      'oneDayShippingAvailable': 'false',
#      'handlingTime': '1'},
#     'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '264.9'},
#      'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '264.9'},
#      'sellingState': 'EndedWithoutSales'},
#     'listingInfo': {'bestOfferEnabled': 'false',
#      'buyItNowAvailable': 'false',
#      'startTime': '2020-06-01T08:24:04.000Z',
#      'endTime': '2020-06-20T13:46:08.000Z',
#      'listingType': 'StoreInventory',
#      'gift': 'false',
#      'watchCount': '3'},
#     'returnsAccepted': 'true',
#     'condition': {'conditionId': '1000',
#      'conditionDisplayName': 'New with box'},
#     'isMultiVariationListing': 'true',
#     'topRatedListing': 'true'},
#    {'itemId': '133425592829',
#     'title': '2020 Nike Air Jordan 13 Flint Retro 414571-404 Mens SIZE 8-14',
#     'globalId': 'EBAY-US',
#     'primaryCategory': {'categoryId': '15709',
#      'categoryName': 'Athletic Shoes'},
#     'galleryURL': 'https://thumbs1.ebaystatic.com/pict/04040_0.jpg',
#     'viewItemURL': 'https://www.ebay.com/itm/2020-Nike-Air-Jordan-13-Flint-Retro-414571-404-Mens-SIZE-8-14-/133425592829?var=0',
#     'paymentMethod': 'PayPal',
#     'autoPay': 'true',
#     'postalCode': '117**',
#     'location': 'Huntington,NY,USA',
#     'country': 'US',
#     'shippingInfo': {'shippingType': 'Calculated',
#      'shipToLocations': 'Worldwide',
#      'expeditedShipping': 'true',
#      'oneDayShippingAvailable': 'false',
#      'handlingTime': '0'},
#     'sellingStatus': {'currentPrice': {'_currencyId': 'USD',
#       'value': '229.99'},
#      'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '229.99'},
#      'sellingState': 'EndedWithoutSales'},
#     'listingInfo': {'bestOfferEnabled': 'false',
#      'buyItNowAvailable': 'false',
#      'startTime': '2020-05-31T13:13:24.000Z',
#      'endTime': '2020-06-20T13:32:59.000Z',
#      'listingType': 'FixedPrice',
#      'gift': 'false',
#      'watchCount': '13'},
#     'returnsAccepted': 'false',
#     'condition': {'conditionId': '1000',
#      'conditionDisplayName': 'New with box'},
#     'isMultiVariationListing': 'true',
#     'topRatedListing': 'false'},
#    {'itemId': '133425592829',
#     'title': '2020 Nike Air Jordan 13 Flint Retro 414571-404 Mens SIZE 8-14',
#     'globalId': 'EBAY-US',
#     'primaryCategory': {'categoryId': '15709',
#      'categoryName': 'Athletic Shoes'},
#     'galleryURL': 'https://thumbs2.ebaystatic.com/pict/1334255928294040_1.jpg',
#     'viewItemURL': 'https://www.ebay.com/itm/2020-Nike-Air-Jordan-13-Flint-Retro-414571-404-Mens-SIZE-8-14-/133425592829?var=432867794664',
#     'paymentMethod': 'PayPal',
#     'autoPay': 'true',
#     'postalCode': '117**',
#     'location': 'Huntington,NY,USA',
#     'country': 'US',
#     'shippingInfo': {'shippingType': 'Calculated',
#      'shipToLocations': 'Worldwide',
#      'expeditedShipping': 'true',
#      'oneDayShippingAvailable': 'false',
#      'handlingTime': '0'},
#     'sellingStatus': {'currentPrice': {'_currencyId': 'USD',
#       'value': '253.99'},
#      'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '253.99'},
#      'sellingState': 'EndedWithoutSales'},
#     'listingInfo': {'bestOfferEnabled': 'false',
#      'buyItNowAvailable': 'false',
#      'startTime': '2020-05-31T13:13:24.000Z',
#      'endTime': '2020-06-20T13:32:59.000Z',
#      'listingType': 'FixedPrice',
#      'gift': 'false'},
#     'returnsAccepted': 'false',
#     'condition': {'conditionId': '1000',
#      'conditionDisplayName': 'New with box'},
#     'isMultiVariationListing': 'true',
#     'topRatedListing': 'false'},
#    {'itemId': '333623006082',
#     'title': '*IN HAND SHIPS TOMORROW* Sz 12 US Air Jordan 13 Retro Flint 2020 NEW',
#     'globalId': 'EBAY-US',
#     'primaryCategory': {'categoryId': '15709',
#      'categoryName': 'Athletic Shoes'},
#     'galleryURL': 'https://thumbs3.ebaystatic.com/m/mUHqfWsoRQZxDL1DmUmAehA/140.jpg',
#     'viewItemURL': 'https://www.ebay.com/itm/IN-HAND-SHIPS-TOMORROW-Sz-12-US-Air-Jordan-13-Retro-Flint-2020-NEW-/333623006082',
#     'paymentMethod': 'PayPal',
#     'autoPay': 'true',
#     'postalCode': '088**',
#     'location': 'Old Bridge,NJ,USA',
#     'country': 'US',
#     'shippingInfo': {'shippingType': 'Calculated',
#      'shipToLocations': 'Worldwide',
#      'expeditedShipping': 'true',
#      'oneDayShippingAvailable': 'false',
#      'handlingTime': '3'},
#     'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '255.0'},
#      'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '255.0'},
#      'sellingState': 'EndedWithSales'},
#     'listingInfo': {'bestOfferEnabled': 'true',
#      'buyItNowAvailable': 'false',
#      'startTime': '2020-06-11T20:42:20.000Z',
#      'endTime': '2020-06-20T12:53:09.000Z',
#      'listingType': 'FixedPrice',
#      'gift': 'false',
#      'watchCount': '3'},
#     'returnsAccepted': 'false',
#     'condition': {'conditionId': '1000',
#      'conditionDisplayName': 'New with box'},
#     'isMultiVariationListing': 'false',
#     'topRatedListing': 'false'},
#    {'itemId': '114246745234',
#     'title': 'Nike Air Jordan 13 Retro Flint 2020 Size 11. Ready To Ship!!!',
#     'globalId': 'EBAY-US',
#     'primaryCategory': {'categoryId': '15709',
#      'categoryName': 'Athletic Shoes'},
#     'galleryURL': 'https://thumbs3.ebaystatic.com/m/mEm8T_AcgLp-uqNvPHWlyeg/140.jpg',
#     'viewItemURL': 'https://www.ebay.com/itm/Nike-Air-Jordan-13-Retro-Flint-2020-Size-11-Ready-Ship-/114246745234',
#     'paymentMethod': 'PayPal',
#     'autoPay': 'true',
#     'postalCode': '700**',
#     'location': 'Luling,LA,USA',
#     'country': 'US',
#     'shippingInfo': {'shippingType': 'Calculated',
#      'shipToLocations': 'Worldwide',
#      'expeditedShipping': 'true',
#      'oneDayShippingAvailable': 'false',
#      'handlingTime': '3'},
#     'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '255.0'},
#      'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '255.0'},
#      'sellingState': 'EndedWithSales'},
#     'listingInfo': {'bestOfferEnabled': 'true',
#      'buyItNowAvailable': 'false',
#      'startTime': '2020-06-03T05:14:12.000Z',
#      'endTime': '2020-06-20T12:16:09.000Z',
#      'listingType': 'FixedPrice',
#      'gift': 'false',
#      'watchCount': '1'},
#     'returnsAccepted': 'false',
#     'condition': {'conditionId': '1000',
#      'conditionDisplayName': 'New with box'},
#     'isMultiVariationListing': 'false',
#     'topRatedListing': 'false'},
#    {'itemId': '313121411830',
#     'title': 'Size 10 US Air Jordan 13 Retro Flint 2020 414571 404',
#     'globalId': 'EBAY-US',
#     'primaryCategory': {'categoryId': '15709',
#      'categoryName': 'Athletic Shoes'},
#     'galleryURL': 'https://thumbs3.ebaystatic.com/m/mLz-wvy6iV_QZz5MMDV6iyA/140.jpg',
#     'viewItemURL': 'https://www.ebay.com/itm/Size-10-US-Air-Jordan-13-Retro-Flint-2020-414571-404-/313121411830',
#     'productId': {'_type': 'ReferenceID', 'value': '12038856423'},
#     'paymentMethod': 'PayPal',
#     'autoPay': 'false',
#     'postalCode': '018**',
#     'location': 'Dracut,MA,USA',
#     'country': 'US',
#     'shippingInfo': {'shippingServiceCost': {'_currencyId': 'USD',
#       'value': '10.0'},
#      'shippingType': 'Flat',
#      'shipToLocations': 'Worldwide',
#      'expeditedShipping': 'true',
#      'oneDayShippingAvailable': 'false',
#      'handlingTime': '3'},
#     'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '270.0'},
#      'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '270.0'},
#      'bidCount': '1',
#      'sellingState': 'EndedWithSales'},
#     'listingInfo': {'bestOfferEnabled': 'false',
#      'buyItNowAvailable': 'false',
#      'startTime': '2020-06-20T11:46:58.000Z',
#      'endTime': '2020-06-20T12:03:35.000Z',
#      'listingType': 'Auction',
#      'gift': 'false'},
#     'returnsAccepted': 'false',
#     'condition': {'conditionId': '1000',
#      'conditionDisplayName': 'New with box'},
#     'isMultiVariationListing': 'false',
#     'topRatedListing': 'false'},
#    {'itemId': '224044027081',
#     'title': 'Nike Air Jordan Retro 13 XIII Flint 2020 - Size 10 - 414571-404',
#     'globalId': 'EBAY-US',
#     'primaryCategory': {'categoryId': '15709',
#      'categoryName': 'Athletic Shoes'},
#     'galleryURL': 'https://thumbs2.ebaystatic.com/m/mQevrySHx_CtVrv6bTs5_GA/140.jpg',
#     'viewItemURL': 'https://www.ebay.com/itm/Nike-Air-Jordan-Retro-13-XIII-Flint-2020-Size-10-414571-404-/224044027081',
#     'paymentMethod': 'PayPal',
#     'autoPay': 'false',
#     'postalCode': '333**',
#     'location': 'Fort Lauderdale,FL,USA',
#     'country': 'US',
#     'shippingInfo': {'shippingType': 'Calculated',
#      'shipToLocations': 'Worldwide',
#      'expeditedShipping': 'true',
#      'oneDayShippingAvailable': 'false',
#      'handlingTime': '3'},
#     'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '249.0'},
#      'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '249.0'},
#      'bidCount': '0',
#      'sellingState': 'EndedWithoutSales'},
#     'listingInfo': {'bestOfferEnabled': 'true',
#      'buyItNowAvailable': 'false',
#      'startTime': '2020-06-13T11:00:55.000Z',
#      'endTime': '2020-06-20T11:00:55.000Z',
#      'listingType': 'Auction',
#      'gift': 'false',
#      'watchCount': '2'},
#     'returnsAccepted': 'false',
#     'condition': {'conditionId': '1000',
#      'conditionDisplayName': 'New with box'},
#     'isMultiVariationListing': 'false',
#     'topRatedListing': 'false'},
#    {'itemId': '133440949348',
#     'title': 'Brand New Nike Air Jordan Retro 13 Flint GS 2020 - Size 6.5Y IN HAND',
#     'globalId': 'EBAY-US',
#     'primaryCategory': {'categoryId': '57929', 'categoryName': "Boys' Shoes"},
#     'galleryURL': 'https://thumbs1.ebaystatic.com/m/mzwWB1RWd5MvMitSjkvrjOQ/140.jpg',
#     'viewItemURL': 'https://www.ebay.com/itm/Brand-New-Nike-Air-Jordan-Retro-13-Flint-GS-2020-Size-6-5Y-HAND-/133440949348',
#     'paymentMethod': 'PayPal',
#     'autoPay': 'true',
#     'postalCode': '995**',
#     'location': 'Anchorage,AK,USA',
#     'country': 'US',
#     'shippingInfo': {'shippingType': 'Calculated',
#      'shipToLocations': 'Worldwide',
#      'expeditedShipping': 'true',
#      'oneDayShippingAvailable': 'false',
#      'handlingTime': '2'},
#     'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '200.0'},
#      'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '200.0'},
#      'sellingState': 'EndedWithSales'},
#     'listingInfo': {'bestOfferEnabled': 'true',
#      'buyItNowAvailable': 'false',
#      'startTime': '2020-06-17T08:10:58.000Z',
#      'endTime': '2020-06-20T07:55:24.000Z',
#      'listingType': 'FixedPrice',
#      'gift': 'false'},
#     'returnsAccepted': 'false',
#     'condition': {'conditionId': '1000',
#      'conditionDisplayName': 'New with box'},
#     'isMultiVariationListing': 'false',
#     'topRatedListing': 'false'},
#    {'itemId': '293611957891',
#     'title': 'DS Size 10.5 Air Jordan 13 Retro Flint 2020 | BRAND NEW | AUTHENTIC',
#     'globalId': 'EBAY-US',
#     'primaryCategory': {'categoryId': '15709',
#      'categoryName': 'Athletic Shoes'},
#     'galleryURL': 'https://thumbs4.ebaystatic.com/m/mFxAat8oIbTTOtxjjxcHm1g/140.jpg',
#     'viewItemURL': 'https://www.ebay.com/itm/DS-Size-10-5-Air-Jordan-13-Retro-Flint-2020-BRAND-NEW-AUTHENTIC-/293611957891',
#     'productId': {'_type': 'ReferenceID', 'value': '12038856423'},
#     'paymentMethod': 'PayPal',
#     'autoPay': 'true',
#     'postalCode': '339**',
#     'location': 'Cape Coral,FL,USA',
#     'country': 'US',
#     'shippingInfo': {'shippingType': 'Calculated',
#      'shipToLocations': 'Worldwide',
#      'expeditedShipping': 'true',
#      'oneDayShippingAvailable': 'false',
#      'handlingTime': '3'},
#     'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '275.0'},
#      'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '275.0'},
#      'bidCount': '0',
#      'sellingState': 'EndedWithoutSales'},
#     'listingInfo': {'bestOfferEnabled': 'false',
#      'buyItNowAvailable': 'true',
#      'buyItNowPrice': {'_currencyId': 'USD', 'value': '370.0'},
#      'convertedBuyItNowPrice': {'_currencyId': 'USD', 'value': '370.0'},
#      'startTime': '2020-06-13T07:26:57.000Z',
#      'endTime': '2020-06-20T07:26:57.000Z',
#      'listingType': 'AuctionWithBIN',
#      'gift': 'false'},
#     'returnsAccepted': 'false',
#     'condition': {'conditionId': '1000',
#      'conditionDisplayName': 'New with box'},
#     'isMultiVariationListing': 'false',
#     'topRatedListing': 'false'},
#    {'itemId': '224046675227',
#     'title': 'Nike Air Jordan Retro 13 Flint Grey Size 11.5 (2020)',
#     'globalId': 'EBAY-US',
#     'primaryCategory': {'categoryId': '15709',
#      'categoryName': 'Athletic Shoes'},
#     'galleryURL': 'https://thumbs4.ebaystatic.com/m/mq1_qyjQQ82w-cCaypgaiUw/140.jpg',
#     'viewItemURL': 'https://www.ebay.com/itm/Nike-Air-Jordan-Retro-13-Flint-Grey-Size-11-5-2020-/224046675227',
#     'paymentMethod': 'PayPal',
#     'autoPay': 'true',
#     'postalCode': '945**',
#     'location': 'Benicia,CA,USA',
#     'country': 'US',
#     'shippingInfo': {'shippingServiceCost': {'_currencyId': 'USD',
#       'value': '0.0'},
#      'shippingType': 'FreePickup',
#      'shipToLocations': 'Worldwide',
#      'expeditedShipping': 'true',
#      'oneDayShippingAvailable': 'false',
#      'handlingTime': '2'},
#     'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '255.0'},
#      'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '255.0'},
#      'sellingState': 'EndedWithSales'},
#     'listingInfo': {'bestOfferEnabled': 'false',
#      'buyItNowAvailable': 'false',
#      'startTime': '2020-06-15T20:21:31.000Z',
#      'endTime': '2020-06-20T06:02:53.000Z',
#      'listingType': 'FixedPrice',
#      'gift': 'false'},
#     'returnsAccepted': 'false',
#     'condition': {'conditionId': '1000',
#      'conditionDisplayName': 'New with box'},
#     'isMultiVariationListing': 'false',
#     'topRatedListing': 'false'},
#    {'itemId': '114262811003',
#     'title': '2020 Air Jordan Retro 13 Flint Grey Navy LIMITED 100% Authentic',
#     'globalId': 'EBAY-US',
#     'primaryCategory': {'categoryId': '15709',
#      'categoryName': 'Athletic Shoes'},
#     'galleryURL': 'https://thumbs1.ebaystatic.com/pict/04040_0.jpg',
#     'viewItemURL': 'https://www.ebay.com/itm/2020-Air-Jordan-Retro-13-Flint-Grey-Navy-LIMITED-100-Authentic-/114262811003?var=0',
#     'paymentMethod': 'PayPal',
#     'autoPay': 'true',
#     'postalCode': '606**',
#     'location': 'Chicago,IL,USA',
#     'country': 'US',
#     'shippingInfo': {'shippingType': 'Calculated',
#      'shipToLocations': 'Worldwide',
#      'expeditedShipping': 'true',
#      'oneDayShippingAvailable': 'false',
#      'handlingTime': '3'},
#     'sellingStatus': {'currentPrice': {'_currencyId': 'USD',
#       'value': '228.88'},
#      'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '228.88'},
#      'sellingState': 'EndedWithoutSales'},
#     'listingInfo': {'bestOfferEnabled': 'false',
#      'buyItNowAvailable': 'false',
#      'startTime': '2020-06-17T05:55:07.000Z',
#      'endTime': '2020-06-20T05:51:24.000Z',
#      'listingType': 'FixedPrice',
#      'gift': 'false',
#      'watchCount': '9'},
#     'returnsAccepted': 'true',
#     'condition': {'conditionId': '1000',
#      'conditionDisplayName': 'New with box'},
#     'isMultiVariationListing': 'true',
#     'topRatedListing': 'false'},
#    {'itemId': '114262811003',
#     'title': '2020 Air Jordan Retro 13 Flint Grey Navy LIMITED 100% Authentic',
#     'globalId': 'EBAY-US',
#     'primaryCategory': {'categoryId': '15709',
#      'categoryName': 'Athletic Shoes'},
#     'galleryURL': 'https://thumbs4.ebaystatic.com/pict/1142628110034040_1.jpg',
#     'viewItemURL': 'https://www.ebay.com/itm/2020-Air-Jordan-Retro-13-Flint-Grey-Navy-LIMITED-100-Authentic-/114262811003?var=414519798205',
#     'paymentMethod': 'PayPal',
#     'autoPay': 'true',
#     'postalCode': '606**',
#     'location': 'Chicago,IL,USA',
#     'country': 'US',
#     'shippingInfo': {'shippingType': 'Calculated',
#      'shipToLocations': 'Worldwide',
#      'expeditedShipping': 'true',
#      'oneDayShippingAvailable': 'false',
#      'handlingTime': '3'},
#     'sellingStatus': {'currentPrice': {'_currencyId': 'USD',
#       'value': '238.88'},
#      'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '238.88'},
#      'sellingState': 'EndedWithoutSales'},
#     'listingInfo': {'bestOfferEnabled': 'false',
#      'buyItNowAvailable': 'false',
#      'startTime': '2020-06-17T05:55:07.000Z',
#      'endTime': '2020-06-20T05:51:24.000Z',
#      'listingType': 'FixedPrice',
#      'gift': 'false',
#      'watchCount': '2'},
#     'returnsAccepted': 'true',
#     'condition': {'conditionId': '1000',
#      'conditionDisplayName': 'New with box'},
#     'isMultiVariationListing': 'true',
#     'topRatedListing': 'false'},
#    {'itemId': '392825268414',
#     'title': 'Nike Air Jordan Retro Flint 13 Grey 2020 Navy Blue White 414571-404 884129-404',
#     'globalId': 'EBAY-US',
#     'primaryCategory': {'categoryId': '15709',
#      'categoryName': 'Athletic Shoes'},
#     'galleryURL': 'https://thumbs3.ebaystatic.com/pict/3928252684144040_1.jpg',
#     'viewItemURL': 'https://www.ebay.com/itm/Nike-Air-Jordan-Retro-Flint-13-Grey-2020-Navy-Blue-White-414571-404-884129-404-/392825268414?var=661731815512',
#     'autoPay': 'true',
#     'postalCode': '390**',
#     'location': 'Clinton,MS,USA',
#     'country': 'US',
#     'shippingInfo': {'shippingServiceCost': {'_currencyId': 'USD',
#       'value': '0.0'},
#      'shippingType': 'Free',
#      'shipToLocations': 'Worldwide',
#      'expeditedShipping': 'true',
#      'oneDayShippingAvailable': 'false',
#      'handlingTime': '2'},
#     'sellingStatus': {'currentPrice': {'_currencyId': 'USD',
#       'value': '189.97'},
#      'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '189.97'},
#      'sellingState': 'EndedWithoutSales'},
#     'listingInfo': {'bestOfferEnabled': 'false',
#      'buyItNowAvailable': 'false',
#      'startTime': '2020-06-04T04:44:17.000Z',
#      'endTime': '2020-06-20T05:44:56.000Z',
#      'listingType': 'StoreInventory',
#      'gift': 'false',
#      'watchCount': '1'},
#     'returnsAccepted': 'true',
#     'condition': {'conditionId': '1000',
#      'conditionDisplayName': 'New with box'},
#     'isMultiVariationListing': 'true',
#     'topRatedListing': 'false'},
#    {'itemId': '363020566688',
#     'title': 'Size 12 US Air Jordan 13 Retro Flint 2020',
#     'globalId': 'EBAY-US',
#     'primaryCategory': {'categoryId': '15709',
#      'categoryName': 'Athletic Shoes'},
#     'galleryURL': 'https://thumbs1.ebaystatic.com/m/mUWMg8swO53kM0Q82USW1Kg/140.jpg',
#     'viewItemURL': 'https://www.ebay.com/itm/Size-12-US-Air-Jordan-13-Retro-Flint-2020-/363020566688',
#     'productId': {'_type': 'ReferenceID', 'value': '19038868194'},
#     'paymentMethod': 'PayPal',
#     'autoPay': 'true',
#     'postalCode': '100**',
#     'location': 'New York,NY,USA',
#     'country': 'US',
#     'shippingInfo': {'shippingType': 'Calculated',
#      'shipToLocations': 'Worldwide',
#      'expeditedShipping': 'true',
#      'oneDayShippingAvailable': 'false',
#      'handlingTime': '3'},
#     'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '250.0'},
#      'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '250.0'},
#      'bidCount': '25',
#      'sellingState': 'EndedWithSales'},
#     'listingInfo': {'bestOfferEnabled': 'false',
#      'buyItNowAvailable': 'false',
#      'startTime': '2020-06-13T05:23:27.000Z',
#      'endTime': '2020-06-20T05:23:27.000Z',
#      'listingType': 'Auction',
#      'gift': 'false',
#      'watchCount': '33'},
#     'returnsAccepted': 'false',
#     'condition': {'conditionId': '1000',
#      'conditionDisplayName': 'New with box'},
#     'isMultiVariationListing': 'false',
#     'topRatedListing': 'false'},
#    {'itemId': '264768308344',
#     'title': 'Nike Air Jordan 13 Retro Flint Grey 2020 GS Size 7y',
#     'globalId': 'EBAY-US',
#     'primaryCategory': {'categoryId': '155202',
#      'categoryName': "Unisex Kids' Shoes"},
#     'galleryURL': 'https://thumbs1.ebaystatic.com/m/mowgnlr3bRSh00XiH3WNrKA/140.jpg',
#     'viewItemURL': 'https://www.ebay.com/itm/Nike-Air-Jordan-13-Retro-Flint-Grey-2020-GS-Size-7y-/264768308344',
#     'paymentMethod': 'PayPal',
#     'autoPay': 'true',
#     'postalCode': '104**',
#     'location': 'Bronx,NY,USA',
#     'country': 'US',
#     'shippingInfo': {'shippingServiceCost': {'_currencyId': 'USD',
#       'value': '0.0'},
#      'shippingType': 'Free',
#      'shipToLocations': 'Worldwide',
#      'expeditedShipping': 'true',
#      'oneDayShippingAvailable': 'false',
#      'handlingTime': '2'},
#     'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '170.0'},
#      'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '170.0'},
#      'sellingState': 'EndedWithSales'},
#     'listingInfo': {'bestOfferEnabled': 'false',
#      'buyItNowAvailable': 'false',
#      'startTime': '2020-06-18T20:04:21.000Z',
#      'endTime': '2020-06-20T05:03:31.000Z',
#      'listingType': 'FixedPrice',
#      'gift': 'false',
#      'watchCount': '2'},
#     'returnsAccepted': 'false',
#     'condition': {'conditionId': '1000',
#      'conditionDisplayName': 'New with box'},
#     'isMultiVariationListing': 'false',
#     'topRatedListing': 'false'},
#    {'itemId': '224024914978',
#     'title': '2020 Nike Air Jordan 13 Flint Retro 414571-404 SIZE: 3.5y-15',
#     'globalId': 'EBAY-US',
#     'primaryCategory': {'categoryId': '15709',
#      'categoryName': 'Athletic Shoes'},
#     'galleryURL': 'https://thumbs3.ebaystatic.com/pict/2240249149784040_2.jpg',
#     'viewItemURL': 'https://www.ebay.com/itm/2020-Nike-Air-Jordan-13-Flint-Retro-414571-404-SIZE-3-5y-15-/224024914978?var=522791519362',
#     'paymentMethod': 'PayPal',
#     'autoPay': 'true',
#     'postalCode': '191**',
#     'location': 'Philadelphia,PA,USA',
#     'country': 'US',
#     'shippingInfo': {'shippingServiceCost': {'_currencyId': 'USD',
#       'value': '0.0'},
#      'shippingType': 'FlatDomesticCalculatedInternational',
#      'shipToLocations': 'Worldwide',
#      'expeditedShipping': 'false',
#      'oneDayShippingAvailable': 'true',
#      'handlingTime': '1'},
#     'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '269.9'},
#      'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '269.9'},
#      'sellingState': 'EndedWithoutSales'},
#     'listingInfo': {'bestOfferEnabled': 'false',
#      'buyItNowAvailable': 'false',
#      'startTime': '2020-05-27T02:34:49.000Z',
#      'endTime': '2020-06-20T04:59:57.000Z',
#      'listingType': 'FixedPrice',
#      'gift': 'false',
#      'watchCount': '10'},
#     'returnsAccepted': 'true',
#     'condition': {'conditionId': '1000',
#      'conditionDisplayName': 'New with box'},
#     'isMultiVariationListing': 'true',
#     'topRatedListing': 'true'},
#    {'itemId': '164249787622',
#     'title': 'Air Jordan 13 Retro Flint 2020 - Size 10.5',
#     'globalId': 'EBAY-US',
#     'primaryCategory': {'categoryId': '15709',
#      'categoryName': 'Athletic Shoes'},
#     'galleryURL': 'https://thumbs3.ebaystatic.com/m/mvlbnsyuRAhmED0Uu6PHwEA/140.jpg',
#     'viewItemURL': 'https://www.ebay.com/itm/Air-Jordan-13-Retro-Flint-2020-Size-10-5-/164249787622',
#     'paymentMethod': 'PayPal',
#     'autoPay': 'false',
#     'postalCode': '974**',
#     'location': 'North Bend,OR,USA',
#     'country': 'US',
#     'shippingInfo': {'shippingType': 'Calculated',
#      'shipToLocations': 'Worldwide',
#      'expeditedShipping': 'true',
#      'oneDayShippingAvailable': 'false',
#      'handlingTime': '1'},
#     'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '240.0'},
#      'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '240.0'},
#      'sellingState': 'EndedWithSales'},
#     'listingInfo': {'bestOfferEnabled': 'false',
#      'buyItNowAvailable': 'false',
#      'startTime': '2020-06-17T22:35:38.000Z',
#      'endTime': '2020-06-20T04:53:30.000Z',
#      'listingType': 'FixedPrice',
#      'gift': 'false',
#      'watchCount': '2'},
#     'returnsAccepted': 'false',
#     'condition': {'conditionId': '1000',
#      'conditionDisplayName': 'New with box'},
#     'isMultiVariationListing': 'false',
#     'topRatedListing': 'false'},
#    {'itemId': '164238744546',
#     'title': 'Size 9 US Air Jordan 13 Retro Flint 2020',
#     'globalId': 'EBAY-US',
#     'primaryCategory': {'categoryId': '15709',
#      'categoryName': 'Athletic Shoes'},
#     'galleryURL': 'https://thumbs3.ebaystatic.com/m/m-Pgtn2Cv6QWcsTRxRtSoZw/140.jpg',
#     'viewItemURL': 'https://www.ebay.com/itm/Size
CA,USA',
#     'country': 'US',
#     'shippingInfo': {'shippingServiceCost': {'_currencyId': 'USD',
#       'value': '12.0'},
#      'shippingType': 'Flat',
#      'shipToLocations': 'Worldwide',
#      'expeditedShipping': 'true',
#      'oneDayShippingAvailable': 'false',
#      'handlingTime': '3'},
#     'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '249.0'},
#      'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '249.0'},
# ...
#     'primaryCategory': {'categoryId': '15709',
#      'categoryName': 'Athletic Shoes'},
#     'galleryURL': 'https://thumbs4.ebaystatic.com/m/mRr97GBuMlWEA3qeY7vGcKw/140.jpg',
#     'viewItemURL': 'https://www.ebay.com/itm/Nike-Air-Jordan-13-Retro-Flint-2020-Mens-Size-12-Blue-Grey-414571-404-Limited-/174314203047',
#     'paymentMethod': 'PayPal',
#     'autoPay': 'true',
#     'postalCode': '945**',
#     'location': 'Fairfield,CA,USA',
#     'country': 'US',
#     'shippingInfo': {'shippingServiceCost': {'_currencyId': 'USD',
#       'value': '10.0'},
#      'shippingType': 'Flat',
#      'shipToLocations': 'Worldwide',
#      'expeditedShipping': 'true',
#      'oneDayShippingAvailable': 'false',
#      'handlingTime': '1'},
#     'sellingStatus': {'currentPrice': {'_currencyId': 'USD',
#       'value': '279.99'},
#      'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '279.99'},
#      'sellingState': 'EndedWithoutSales'},
#     'listingInfo': {'bestOfferEnabled': 'false',
#      'buyItNowAvailable': 'false',
#      'startTime': '2020-06-12T03:35:01.000Z',
#      'endTime': '2020-06-19T16:32:56.000Z',
#      'listingType': 'StoreInventory',
#      'gift': 'false',
#      'watchCount': '6'},
#     'returnsAccepted': 'true',
#     'condition': {'conditionId': '1000',
#      'conditionDisplayName': 'New with box'},
#     'isMultiVariationListing': 'false',
#     'topRatedListing': 'true'},
#    {'itemId': '383573914319',
#     'title': 'Size 7 US Air Jordan 13 Retro Flint 2020 *Ready To Ship*',
#     'globalId': 'EBAY-US',
#     'primaryCategory': {'categoryId': '15709',
#      'categoryName': 'Athletic Shoes'},
#     'galleryURL': 'https://thumbs4.ebaystatic.com/m/mHDSPd9kfS_4JVQIkGbo9YQ/140.jpg',
#     'viewItemURL': 'https://www.ebay.com/itm/Size-7-US-Air-Jordan-13-Retro-Flint-2020-Ready-Ship-/383573914319',
#     'productId': {'_type': 'ReferenceID', 'value': '2309918317'},
#     'paymentMethod': 'PayPal',
#     'autoPay': 'true',
#     'postalCode': '313**',
#     'location': 'Pooler,GA,USA',
#     'country': 'US',
#     'shippingInfo': {'shippingServiceCost': {'_currencyId': 'USD',
#       'value': '0.0'},
#      'shippingType': 'Free',
#      'shipToLocations': 'Worldwide',
#      'expeditedShipping': 'true',
#      'oneDayShippingAvailable': 'false',
#      'handlingTime': '3'},
#     'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '195.0'},
#      'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '195.0'},
#      'sellingState': 'EndedWithSales'},
#     'listingInfo': {'bestOfferEnabled': 'true',
#      'buyItNowAvailable': 'false',
#      'startTime': '2020-06-03T23:42:00.000Z',
#      'endTime': '2020-06-19T15:52:16.000Z',
#      'listingType': 'FixedPrice',
#      'gift': 'false',
#      'watchCount': '9'},
#     'returnsAccepted': 'false',
#     'condition': {'conditionId': '1000',
#      'conditionDisplayName': 'New with box'},
#     'isMultiVariationListing': 'false',
#     'topRatedListing': 'false'},
#    {'itemId': '303594526269',
#     'title': 'Size 7 US Air Jordan 13 Retro Flint 2020',
#     'globalId': 'EBAY-US',
#     'primaryCategory': {'categoryId': '57929', 'categoryName': "Boys' Shoes"},
#     'galleryURL': 'https://thumbs2.ebaystatic.com/m/m07bfyDLZn9TDBhHSmnC0uQ/140.jpg',
#     'viewItemURL': 'https://www.ebay.com/itm/Size-7-US-Air-Jordan-13-Retro-Flint-2020-/303594526269',
#     'paymentMethod': 'PayPal',
#     'autoPay': 'false',
#     'postalCode': '199**',
#     'location': 'Smyrna,DE,USA',
#     'country': 'US',
#     'shippingInfo': {'shippingServiceCost': {'_currencyId': 'USD',
#       'value': '10.0'},
#      'shippingType': 'Flat',
#      'shipToLocations': 'Worldwide',
#      'expeditedShipping': 'true',
#      'oneDayShippingAvailable': 'false',
#      'handlingTime': '3'},
#     'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '81.0'},
#      'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '81.0'},
#      'bidCount': '1',
#      'sellingState': 'EndedWithoutSales'},
#     'listingInfo': {'bestOfferEnabled': 'false',
#      'buyItNowAvailable': 'true',
#      'buyItNowPrice': {'_currencyId': 'USD', 'value': '200.0'},
#      'convertedBuyItNowPrice': {'_currencyId': 'USD', 'value': '200.0'},
#      'startTime': '2020-06-12T15:49:44.000Z',
#      'endTime': '2020-06-19T15:49:44.000Z',
#      'listingType': 'AuctionWithBIN',
#      'gift': 'false'},
#     'returnsAccepted': 'false',
#     'condition': {'conditionId': '1000',
#      'conditionDisplayName': 'New with box'},
#     'isMultiVariationListing': 'false',
#     'topRatedListing': 'false'},
#    {'itemId': '392841181794',
#     'title': 'Size 11 US Air Jordan 13 Retro Flint 2020',
#     'globalId': 'EBAY-US',
#     'primaryCategory': {'categoryId': '15709',
#      'categoryName': 'Athletic Shoes'},
#     'galleryURL': 'https://thumbs3.ebaystatic.com/m/mO2T1as4wOIDoOUfEwRppuA/140.jpg',
#     'viewItemURL': 'https://www.ebay.com/itm/Size-11-US-Air-Jordan-13-Retro-Flint-2020-/392841181794',
#     'paymentMethod': 'PayPal',
#     'autoPay': 'true',
#     'postalCode': '114**',
#     'location': 'Woodhaven,NY,USA',
#     'country': 'US',
#     'shippingInfo': {'shippingServiceCost': {'_currencyId': 'USD',
#       'value': '0.0'},
#      'shippingType': 'Free',
#      'shipToLocations': 'Worldwide',
#      'expeditedShipping': 'true',
#      'oneDayShippingAvailable': 'false',
#      'handlingTime': '2'},
#     'sellingStatus': {'currentPrice': {'_currencyId': 'USD',
#       'value': '249.99'},
#      'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '249.99'},
#      'sellingState': 'EndedWithSales'},
#     'listingInfo': {'bestOfferEnabled': 'false',
#      'buyItNowAvailable': 'false',
#      'startTime': '2020-06-16T22:44:41.000Z',
#      'endTime': '2020-06-19T15:41:24.000Z',
#      'listingType': 'FixedPrice',
#      'gift': 'false',
#      'watchCount': '9'},
#     'returnsAccepted': 'false',
#     'condition': {'conditionId': '1000',
#      'conditionDisplayName': 'New with box'},
#     'isMultiVariationListing': 'false',
#     'topRatedListing': 'false'},
#    {'itemId': '153972207043',
#     'title': 'Air Jordan 13 Retro Flint 2020 size 11',
#     'globalId': 'EBAY-US',
#     'primaryCategory': {'categoryId': '15709',
#      'categoryName': 'Athletic Shoes'},
#     'galleryURL': 'https://thumbs4.ebaystatic.com/m/mL6Aq4Gnjwwa36WNsENUSwg/140.jpg',
#     'viewItemURL': 'https://www.ebay.com/itm/Air-Jordan-13-Retro-Flint-2020-size-11-/153972207043',
#     'productId': {'_type': 'ReferenceID', 'value': '2309918260'},
#     'paymentMethod': 'PayPal',
#     'autoPay': 'true',
#     'postalCode': '193**',
#     'location': 'West Chester,PA,USA',
#     'country': 'US',
#     'shippingInfo': {'shippingType': 'Calculated',
#      'shipToLocations': 'Worldwide',
#      'expeditedShipping': 'true',
#      'oneDayShippingAvailable': 'false',
#      'handlingTime': '3'},
#     'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '240.0'},
#      'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '240.0'},
#      'sellingState': 'EndedWithSales'},
#     'listingInfo': {'bestOfferEnabled': 'true',
#      'buyItNowAvailable': 'false',
#      'startTime': '2020-06-15T07:03:50.000Z',
#      'endTime': '2020-06-19T14:50:43.000Z',
#      'listingType': 'FixedPrice',
#      'gift': 'false',
#      'watchCount': '2'},
#     'returnsAccepted': 'false',
#     'condition': {'conditionId': '1000',
#      'conditionDisplayName': 'New with box'},
#     'isMultiVariationListing': 'false',
#     'topRatedListing': 'false'},
#    {'itemId': '303596478209',
#     'title': 'Size 9.5 Nike Air Jordan 13 Retro Flint 2020',
#     'globalId': 'EBAY-US',
#     'primaryCategory': {'categoryId': '15709',
#      'categoryName': 'Athletic Shoes'},
#     'galleryURL': 'https://thumbs2.ebaystatic.com/m/mVRTPeAOERhdiGpn4U856Jg/140.jpg',
#     'viewItemURL': 'https://www.ebay.com/itm/Size-9-5-Nike-Air-Jordan-13-Retro-Flint-2020-/303596478209',
#     'paymentMethod': 'PayPal',
#     'autoPay': 'false',
#     'postalCode': '981**',
#     'location': 'Seattle,WA,USA',
#     'country': 'US',
#     'shippingInfo': {'shippingServiceCost': {'_currencyId': 'USD',
#       'value': '10.0'},
#      'shippingType': 'Flat',
#      'shipToLocations': 'Worldwide',
#      'expeditedShipping': 'true',
#      'oneDayShippingAvailable': 'false',
#      'handlingTime': '3'},
#     'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '244.0'},
#      'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '244.0'},
#      'sellingState': 'EndedWithSales'},
#     'listingInfo': {'bestOfferEnabled': 'false',
#      'buyItNowAvailable': 'false',
#      'startTime': '2020-06-14T22:50:32.000Z',
#      'endTime': '2020-06-19T14:34:17.000Z',
#      'listingType': 'FixedPrice',
#      'gift': 'false',
#      'watchCount': '3'},
#     'returnsAccepted': 'false',
#     'condition': {'conditionId': '1000',
#      'conditionDisplayName': 'New with box'},
#     'isMultiVariationListing': 'false',
#     'topRatedListing': 'false'},
#    {'itemId': '264762637428',
#     'title': 'Size 13 US Air Jordan 13 Retro Flint 2020 *IN HAND READY TO SHIP* Deadstock',
#     'globalId': 'EBAY-US',
#     'primaryCategory': {'categoryId': '15709',
#      'categoryName': 'Athletic Shoes'},
#     'galleryURL': 'https://thumbs1.ebaystatic.com/m/mfG5c4HYbYNYUuIyKSaUPVQ/140.jpg',
#     'viewItemURL': 'https://www.ebay.com/itm/Size-13-US-Air-Jordan-13-Retro-Flint-2020-IN-HAND-READY-SHIP-Deadstock-/264762637428',
#     'paymentMethod': 'PayPal',
#     'autoPay': 'true',
#     'postalCode': '714**',
#     'location': 'Fort Polk,LA,USA',
#     'country': 'US',
#     'shippingInfo': {'shippingType': 'Calculated',
#      'shipToLocations': 'Worldwide',
#      'expeditedShipping': 'true',
#      'oneDayShippingAvailable': 'false',
#      'handlingTime': '3'},
#     'sellingStatus': {'currentPrice': {'_currencyId': 'USD',
#       'value': '244.95'},
#      'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '244.95'},
#      'sellingState': 'EndedWithSales'},
#     'listingInfo': {'bestOfferEnabled': 'true',
#      'buyItNowAvailable': 'false',
#      'startTime': '2020-06-13T14:11:00.000Z',
#      'endTime': '2020-06-19T14:12:28.000Z',
#      'listingType': 'FixedPrice',
#      'gift': 'false',
#      'watchCount': '1'},
#     'returnsAccepted': 'false',
#     'condition': {'conditionId': '1000',
#      'conditionDisplayName': 'New with box'},
#     'isMultiVariationListing': 'false',
#     'topRatedListing': 'false'},
#    {'itemId': '264762657048',
#     'title': 'Nike Air Jordan Retro 13 FLINT Grey 2020 Navy Blue White | 884129-404 | GS 4Y-7Y',
#     'globalId': 'EBAY-US',
#     'subtitle': '✅✅✅FAST SHIPPING✅✅✅USPS PRIORITY WITH TRACKING✅✅✅',
#     'primaryCategory': {'categoryId': '15709',
#      'categoryName': 'Athletic Shoes'},
#     'galleryURL': 'https://thumbs1.ebaystatic.com/pict/2647626570484040_1.jpg',
#     'viewItemURL': 'https://www.ebay.com/itm/Nike-Air-Jordan-Retro-13-FLINT-Grey-2020-Navy-Blue-White-884129-404-GS-4Y-7Y-/264762657048?var=564588095834',
#     'paymentMethod': 'PayPal',
#     'autoPay': 'true',
#     'postalCode': '926**',
#     'location': 'Westminster,CA,USA',
#     'country': 'US',
#     'shippingInfo': {'shippingServiceCost': {'_currencyId': 'USD',
#       'value': '0.0'},
#      'shippingType': 'Free',
#      'shipToLocations': 'Worldwide',
#      'expeditedShipping': 'true',
#      'oneDayShippingAvailable': 'false',
#      'handlingTime': '1'},
#     'sellingStatus': {'currentPrice': {'_currencyId': 'USD',
#       'value': '189.99'},
#      'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '189.99'},
#      'sellingState': 'EndedWithoutSales'},
#     'listingInfo': {'bestOfferEnabled': 'false',
#      'buyItNowAvailable': 'false',
#      'startTime': '2020-06-13T14:33:41.000Z',
#      'endTime': '2020-06-19T13:54:55.000Z',
#      'listingType': 'StoreInventory',
#      'gift': 'false',
#      'watchCount': '12'},
#     'returnsAccepted': 'false',
#     'condition': {'conditionId': '1000',
#      'conditionDisplayName': 'New with box'},
#     'isMultiVariationListing': 'true',
#     'topRatedListing': 'false'},
#    {'itemId': '313113989859',
#     'title': 'Jordan 13 Retro Flint Size 8 (2020) 100% Authentic',
#     'globalId': 'EBAY-US',
#     'primaryCategory': {'categoryId': '15709',
#      'categoryName': 'Athletic Shoes'},
#     'galleryURL': 'https://thumbs4.ebaystatic.com/m/m1Sn917aXjo6wR8zC59aOnQ/140.jpg',
#     'viewItemURL': 'https://www.ebay.com/itm/Jordan-13-Retro-Flint-Size-8-2020-100-Authentic-/313113989859',
#     'paymentMethod': 'PayPal',
#     'autoPay': 'true',
#     'postalCode': '199**',
#     'location': 'Bridgeville,DE,USA',
#     'country': 'US',
#     'shippingInfo': {'shippingType': 'Calculated',
#      'shipToLocations': 'Worldwide',
#      'expeditedShipping': 'true',
#      'oneDayShippingAvailable': 'false',
#      'handlingTime': '3'},
#     'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '225.0'},
#      'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '225.0'},
#      'sellingState': 'EndedWithSales'},
#     'listingInfo': {'bestOfferEnabled': 'true',
#      'buyItNowAvailable': 'false',
#      'startTime': '2020-06-12T14:03:29.000Z',
#      'endTime': '2020-06-19T13:47:59.000Z',
#      'listingType': 'FixedPrice',
#      'gift': 'false',
#      'watchCount': '6'},
#     'returnsAccepted': 'true',
#     'condition': {'conditionId': '1000',
#      'conditionDisplayName': 'New with box'},
#     'isMultiVariationListing': 'false',
#     'topRatedListing': 'false'},
#    {'itemId': '143629745617',
#     'title': 'Air Jordan 13 Retro Flint 2020 (Size 10)',
#     'globalId': 'EBAY-US',
#     'primaryCategory': {'categoryId': '15709',
#      'categoryName': 'Athletic Shoes'},
#     'galleryURL': 'https://thumbs2.ebaystatic.com/m/mJ4um5bPXJYl_37XB_UK34g/140.jpg',
#     'viewItemURL': 'https://www.ebay.com/itm/Air-Jordan-13-Retro-Flint-2020-Size-10-/143629745617',
#     'paymentMethod': 'PayPal',
#     'autoPay': 'true',
#     'postalCode': '708**',
#     'location': 'Baton Rouge,LA,USA',
#     'country': 'US',
#     'shippingInfo': {'shippingType': 'Calculated',
#      'shipToLocations': 'Worldwide',
#      'expeditedShipping': 'true',
#      'oneDayShippingAvailable': 'false',
#      'handlingTime': '3'},
#     'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '212.5'},
#      'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '212.5'},
#      'bidCount': '9',
#      'sellingState': 'EndedWithSales'},
#     'listingInfo': {'bestOfferEnabled': 'false',
#      'buyItNowAvailable': 'false',
#      'startTime': '2020-06-12T13:19:23.000Z',
#      'endTime': '2020-06-19T13:19:23.000Z',
#      'listingType': 'Auction',
#      'gift': 'false',
#      'watchCount': '20'},
#     'returnsAccepted': 'false',
#     'condition': {'conditionId': '1000',
#      'conditionDisplayName': 'New with box'},
#     'isMultiVariationListing': 'false',
#     'topRatedListing': 'false'},
#    {'itemId': '373088106553',
#     'title': 'Air Jordan Retro 13 Flint 2020 - GS SIZE 6.5 Y',
#     'globalId': 'EBAY-US',
#     'primaryCategory': {'categoryId': '15709',
#      'categoryName': 'Athletic Shoes'},
#     'galleryURL': 'https://thumbs2.ebaystatic.com/m/mL0TBQfCihGZJWQhxPoOweA/140.jpg',
#     'viewItemURL': 'https://www.ebay.com/itm/Air-Jordan-Retro-13-Flint-2020-GS-SIZE-6-5-Y-/373088106553',
#     'paymentMethod': 'PayPal',
#     'autoPay': 'false',
#     'postalCode': '630**',
#     'location': 'Saint Ann,MO,USA',
#     'country': 'US',
#     'shippingInfo': {'shippingType': 'Calculated',
#      'shipToLocations': 'Worldwide',
#      'expeditedShipping': 'true',
#      'oneDayShippingAvailable': 'false',
#      'handlingTime': '3'},
#     'sellingStatus': {'currentPrice': {'_currencyId': 'USD', 'value': '160.0'},
#      'convertedCurrentPrice': {'_currencyId': 'USD', 'value': '160.0'},
#      'bidCount': '1',
#      'sellingState': 'EndedWithSales'},
#     'listingInfo': {'bestOfferEnabled': 'false',
#      'buyItNowAvailable': 'false',
#      'startTime': '2020-06-19T08:10:52.000Z',
#      'endTime': '2020-06-19T13:18:04.000Z',
#      'listingType': 'Auction',
#      'gift': 'false'},
#     'returnsAccepted': 'false',
#     'condition': {'conditionId': '1000',
#      'conditionDisplayName': 'New with box'},
#     'isMultiVariationListing': 'false',
#     'topRatedListing': 'false'}],
#   '_count': '100'},
#  'paginationOutput': {'pageNumber': '2',
#   'entriesPerPage': '100',
#   'totalPages': '70',
#   'totalEntries': '6963'}}

# %%
from ebaysdk.shopping import Connection as Shopping

api = Shopping(appid='SoleML--PRD-a2eba3d7e-8cd42d5c', config_file=None)
# Pass in multiple product ids to get the individual sizes...
# For multiple item listings, figure out a work around
ItemID=['233605037047']
response = api.execute('GetMultipleItems', {'ItemID':ItemID, 'IncludeSelector':'ItemSpecifics'})
response.dict()
# Out:
# {'Timestamp': '2020-06-21T05:28:09.437Z',
#  'Ack': 'Success',
#  'Build': 'E1141_CORE_APILW_19170841_R1',
#  'Version': '1141',
#  'Item': {'ItemID': '233605037047',
#   'EndTime': '2020-06-20T14:11:29.000Z',
#   'ViewItemURLForNaturalSearch': 'https://www.ebay.com/itm/2020-Nike-Air-Jordan-13-Flint-Retro-Order-Confirmed-MULTIPLE-SIZES-AVAILABLE-/233605037047?var=',
#   'ListingType': 'FixedPriceItem',
#   'Location': 'Pittsburgh, Pennsylvania',
#   'PictureURL': ['https://i.ebayimg.com/00/s/Nzk5WDExNDA=/z/iaUAAOSwzhle02Bq/$_57.JPG?set_id=8800005007'],
#   'PrimaryCategoryID': '15709',
#   'PrimaryCategoryName': "Clothing, Shoes & Accessories:Men:Men's Shoes:Athletic Shoes",
#   'BidCount': '0',
#   'ConvertedCurrentPrice': {'_currencyID': 'USD', 'value': '260.0'},
#   'ListingStatus': 'Completed',
#   'TimeLeft': 'PT0S',
#   'Title': '2020 Nike Air Jordan 13 Flint Retro Order Confirmed MULTIPLE SIZES AVAILABLE!',
#   'ItemSpecifics': {'NameValueList': [{'Name': 'Character',
#      'Value': 'Grey Wolf'},
#     {'Name': 'Model', 'Value': 'Jordan 13'},
#     {'Name': 'Department', 'Value': 'Men'},
#     {'Name': 'Product Line', 'Value': 'Nike Air'},
#     {'Name': 'Theme', 'Value': 'Colorful'},
#     {'Name': 'Style', 'Value': 'Athletic Sneakers'},
#     {'Name': 'Idset_Mpn', 'Value': '378037-61'},
#     {'Name': 'Size', 'Value': 'Select'},
#     {'Name': 'Type', 'Value': 'Athletic'},
#     {'Name': 'Year of Manufacture', 'Value': '2020'},
#     {'Name': 'Features', 'Value': 'Retro'},
#     {'Name': 'Color', 'Value': 'Flint'},
#     {'Name': 'Brand', 'Value': 'Jordan'}]},
#   'HitCount': '699',
#   'Country': 'US',
#   'AutoPay': 'false',
#   'ConditionID': '1000',
#   'ConditionDisplayName': 'New with box',
#   'GlobalShipping': 'true'}}

# %%
## Loop through the completed listings... flag all items that are multivariation
## save links of these items and scrap them manually using requests and BS4
## then implement the eBay last scraped portion on MongoDB
